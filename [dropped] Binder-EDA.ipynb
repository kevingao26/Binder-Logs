# %%
'''
# !pip install pyyaml
# !pip install matplotlib-venn
# !pip install numpy
'''
# Out:
# '\n!pip install pyyaml\n!pip install matplotlib-venn\n!pip install numpy\n'

# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
sns.set_style("whitegrid")
from pprint import pprint
import sqlite3
import yaml
import re
import datetime

try: # for pip >= 10
    from pip._internal.req import parse_requirements
except ImportError: # for pip <= 9.0.3
    from pip.req import parse_requirements

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline

# Code for hiding seaborn warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Easier navigation:
#
# ------------------------------------
#
# ### 1. <a href='#setup'>Setup</a>
# ### 2. <a href='#merge'>Merging</a>
# ------------------------------------
# ### 3.  <a href='#specs'>Binder-Specs-EDA w/ clean_specs</a>
#
# ------------------------------------

# %% [markdown]
# <a name='setup'></a>
# ## 1. Setup
#
# <br>

# %%
dash = '-' * 60

# %% [markdown]
# ### *events Table*

# %%
con = sqlite3.connect('binder.sqlite')
df1 = pd.read_sql('SELECT * FROM events', con)

# %%
df1.columns
# Out:
# Index(['version', 'timestamp', 'provider', 'spec', 'origin', 'ref',
#        'guessed_ref'],
#       dtype='object')

# %%
df1
# Out:
#           version                  timestamp provider  \
# 0               1  2018-11-03T00:00:00+00:00   GitHub
# 1               1  2018-11-03T00:00:00+00:00   GitHub
# 2               1  2018-11-03T00:00:00+00:00   GitHub
# 3               1  2018-11-03T00:01:00+00:00   GitHub
# 4               1  2018-11-03T00:01:00+00:00   GitHub
# ...           ...                        ...      ...
# 18230449        4  2021-06-06T23:58:00+00:00   GitHub
# 18230450        4  2021-06-06T23:58:00+00:00   GitHub
# 18230451        4  2021-06-06T23:58:00+00:00   GitHub
# 18230452        4  2021-06-06T23:58:00+00:00   GitHub
# 18230453        4  2021-06-06T23:59:00+00:00   GitHub
#
#                                        spec            origin  \
# 0             Qiskit/qiskit-tutorial/master              None
# 1           ipython/ipython-in-depth/master              None
# 2             QISKit/qiskit-tutorial/master              None
# 3             QISKit/qiskit-tutorial/master              None
# 4         jupyterlab/jupyterlab-demo/master              None
# ...                                     ...               ...
# 18230449  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230450  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230451  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230452  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230453        numba/numba-examples/master  gke.mybinder.org
#
#                                                ref  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# ...                                            ...
# 18230449  5a5eb6bb04250b199a1cbb529e744075216a17a5
# 18230450  5a5eb6bb04250b199a1cbb529e744075216a17a5
# 18230451  5a5eb6bb04250b199a1cbb529e744075216a17a5
# 18230452  5a5eb6bb04250b199a1cbb529e744075216a17a5
# 18230453  4efb2a16dca28c1374be48dfaf4636d5bf167eba
#
#                                        guessed_ref
# 0         27d67cc4485ebfebae2b36b4856f1cea9fc7f693
# 1         7e5ce96cc9251083979efdfc393425f1229a4a68
# 2         27d67cc4485ebfebae2b36b4856f1cea9fc7f693
# 3         27d67cc4485ebfebae2b36b4856f1cea9fc7f693
# 4         79184a07d47cf03787b39cfc345da98794d76554
# ...                                            ...
# 18230449                                      None
# 18230450                                      None
# 18230451                                      None
# 18230452                                      None
# 18230453                                      None
#
# [18230454 rows x 7 columns]

# %% [markdown]
# ### *spec_files Table*

# %%
con = sqlite3.connect('binder.sqlite')
df2 = pd.read_sql('SELECT * FROM spec_files', con)

# %%
df2.columns
# Out:
# Index(['ref', 'ls', 'runtime', 'apt', 'conda', 'pip', 'pipfile', 'julia', 'r',
#        'nix', 'docker', 'setup', 'postbuild', 'start'],
#       dtype='object')

# %%
df2
# Out:
#                                              ref  \
# 0       ab1be186a74c81c83f863bc3b6258fee46eeca56
# 1       9267f689d1935f5670e00d63b4f9639226f599ec
# 2       2fccf878bf9db2239207b39761d2fc9a78494610
# 3       6c2b3723a3b7251a9b4df7d6fd9f0079b8df2ac1
# 4       6464ab1b75787590096275bf36b6e3035f23d2ab
# ...                                          ...
# 178394  394381cccbbd63122129a09ca38775731901e1eb
# 178395  64831e2cc32a4877c669b3d16156be7e2d25507d
# 178396  2d5f216e18ac6ea8adc7f658d9bd344a49e7289c
# 178397  95b20d80709832d340600461a86417ca5003bf7c
# 178398  89e97490d0c4cafd6da3ddab012d141df356acec
#
#                                                        ls  \
# 0       {".ipynb_checkpoints": {"I. Python and Jupyter...
# 1                                  {"test_script.R": 115}
# 2       {".ipynb_checkpoints": {"binder-example-checkp...
# 3       {".Rbuildignore": 14, ".binder": {"Dockerfile"...
# 4       {".gitignore": 29, "README.md": 533, "index.ip...
# ...                                                   ...
# 178394  {".gitignore": 254, ".gitmodules": 323, ".read...
# 178395  {".gitignore": 40, "README.md": 1982, "SMBE202...
# 178396  {".gitignore": 625, "LICENSE": 2615, "README.m...
# 178397  {".gitignore": 1798, "bear_classifier.ipynb": ...
# 178398  {".azure-pipelines": {"azure-pipelines.yml": 1...
#
#                       runtime  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ...                       ...
# 178394                   None
# 178395  b'r-3.6-2021-05-26\n'
# 178396                   None
# 178397                   None
# 178398                   None
#
#                                                       apt  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 178394                                               None
# 178395  b'libudunits2-dev\ngdal-bin\nlibgdal-dev\nlibg...
# 178396                                               None
# 178397                                               None
# 178398                                               None
#
#                                                     conda  \
# 0                                                    None
# 1                                                    None
# 2       name: binder-example\ndependencies:\n    - pyt...
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 178394                                               None
# 178395                                               None
# 178396  b'name: bestiapop\r\nchannels:\r\n  - conda-fo...
# 178397                                               None
# 178398  b'name: bayesian-modelling-tutorial\nchannels:...
#
#                                                       pip pipfile julia  \
# 0       numpy==1.18.5\npandas==1.0.5\nfuzzywuzzy==0.18...    None  None
# 1                                                    None    None  None
# 2                                                    None    None  None
# 3                                                    None    None  None
# 4       requests==2.24.0\nnumpy==1.19.2\nmatplotlib==3...    None  None
# ...                                                   ...     ...   ...
# 178394                                               None    None  None
# 178395                                               None    None  None
# 178396                                               None    None  None
# 178397  b'voila\nfastai>=2\npillow<7\npackaging\nipywi...    None  None
# 178398                                               None    None  None
#
#                                                         r   nix  \
# 0                                                    None  None
# 1                                                    None  None
# 2                                                    None  None
# 3                                                    None  None
# 4                                                    None  None
# ...                                                   ...   ...
# 178394                                               None  None
# 178395  b'install.packages("devtools")\ninstall.packag...  None
# 178396                                               None  None
# 178397                                               None  None
# 178398                                               None  None
#
#                                                    docker  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3       FROM rocker/binder:3.6.0\nLABEL maintainer='Mi...
# 4                                                    None
# ...                                                   ...
# 178394                                               None
# 178395                                               None
# 178396                                               None
# 178397                                               None
# 178398                                               None
#
#                                                     setup  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 178394                                               None
# 178395                                               None
# 178396  b'import sys\r\nfrom setuptools import setup\r...
# 178397                                               None
# 178398                                               None
#
#                                                 postbuild start
# 0                                                    None  None
# 1                                                    None  None
# 2                                                    None  None
# 3                                                    None  None
# 4                                                    None  None
# ...                                                   ...   ...
# 178394  b'#!/usr/bin/env bash\n\npython3 -m pip instal...  None
# 178395  b'mkdir bin\n\n# installation instructions fro...  None
# 178396                                               None  None
# 178397                                               None  None
# 178398                                               None  None
#
# [178399 rows x 14 columns]

# %% [markdown]
# ### *clean_specs Table*

# %%
con = sqlite3.connect('binder.sqlite')
df3 = pd.read_sql('SELECT * FROM clean_specs', con)

# %%
df3.columns
# Out:
# Index(['ref', 'conda_channels', 'conda_packages', 'pip_packages',
#        'apt_packages'],
#       dtype='object')

# %%
df3
# Out:
#                                              ref  \
# 0       ab1be186a74c81c83f863bc3b6258fee46eeca56
# 1       9267f689d1935f5670e00d63b4f9639226f599ec
# 2       2fccf878bf9db2239207b39761d2fc9a78494610
# 3       6c2b3723a3b7251a9b4df7d6fd9f0079b8df2ac1
# 4       6464ab1b75787590096275bf36b6e3035f23d2ab
# ...                                          ...
# 159641  394381cccbbd63122129a09ca38775731901e1eb
# 159642  64831e2cc32a4877c669b3d16156be7e2d25507d
# 159643  2d5f216e18ac6ea8adc7f658d9bd344a49e7289c
# 159644  95b20d80709832d340600461a86417ca5003bf7c
# 159645  89e97490d0c4cafd6da3ddab012d141df356acec
#
#                                            conda_channels  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 159641                                               None
# 159642                                               None
# 159643                        ["conda-forge", "defaults"]
# 159644                                               None
# 159645  ["conda-forge", "defaults", "anaconda", "ericm...
#
#                                            conda_packages  \
# 0                                                    None
# 1                                                    None
# 2         ["python=3.7", "numpy", "pandas", "matplotlib"]
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 159641                                               None
# 159642                                               None
# 159643  ["python=3.7", "jinja2", "netcdf4", "tqdm", "r...
# 159644                                               None
# 159645  ["python[version='>=3.8']", "jupyter", "jupyte...
#
#                                              pip_packages  \
# 0       ["numpy==1.18.5", "pandas==1.0.5", "fuzzywuzzy...
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4       ["requests==2.24.0", "numpy==1.19.2", "matplot...
# ...                                                   ...
# 159641                                               None
# 159642                                               None
# 159643                                      ["bestiapop"]
# 159644  ["voila", "fastai>=2", "pillow<7", "packaging"...
# 159645  ["mkdocs", "mkdocs-material", "mknotebooks", "...
#
#                                              apt_packages
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 159641                                               None
# 159642  ["libudunits2-dev", "gdal-bin", "libgdal-dev",...
# 159643                                               None
# 159644                                               None
# 159645                                               None
#
# [159646 rows x 5 columns]

# %% [markdown]
# <a name='merge'></a>
# ## 2. Merging
#
# <br>

# %% [markdown]
# Strategy: take the latest ref from `events` and merge that with the entries in `spec_files`. They have about the same amount of rows after `events` is filtered down to just its latest entries.

# %%
len(df1["ref"].unique())
# Out:
# 201676

# %%
df1[df1["ref"].notnull()]
# Out:
#           version                  timestamp provider  \
# 9391434         4  2020-06-18T16:41:00+00:00      Git
# 9391436         4  2020-06-18T16:41:00+00:00   GitHub
# 9391437         4  2020-06-18T16:41:00+00:00   GitHub
# 9391438         4  2020-06-18T16:41:00+00:00   GitHub
# 9391439         4  2020-06-18T16:41:00+00:00   GitHub
# ...           ...                        ...      ...
# 18230449        4  2021-06-06T23:58:00+00:00   GitHub
# 18230450        4  2021-06-06T23:58:00+00:00   GitHub
# 18230451        4  2021-06-06T23:58:00+00:00   GitHub
# 18230452        4  2021-06-06T23:58:00+00:00   GitHub
# 18230453        4  2021-06-06T23:59:00+00:00   GitHub
#
#                                                        spec            origin  \
# 9391434   https://bitbucket.org/fsmeraldi/jupytermarking...  gke.mybinder.org
# 9391436                  leosamu/pythonMoocCompanion/master  gke.mybinder.org
# 9391437          jupyterlab/jupyterlab-demo/try.jupyter.org  gke.mybinder.org
# 9391438                     ipython/ipython-in-depth/master  gke.mybinder.org
# 9391439                          SamLau95/nbinteract/master  gke.mybinder.org
# ...                                                     ...               ...
# 18230449                  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230450                  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230451                  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230452                  jupyterlab/jupyterlab-demo/master  gke.mybinder.org
# 18230453                        numba/numba-examples/master  gke.mybinder.org
#
#                                                ref guessed_ref
# 9391434   d22a4b0a494b25ad9e0397b44d9abc3461eb6309        None
# 9391436   e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# 9391437   71b616307dcb9cba18262d8e5fa46ad828ca51e4        None
# 9391438   7e5ce96cc9251083979efdfc393425f1229a4a68        None
# 9391439   502b0a8e5f6236ed23d4a3d0dcc22db72f6d31e4        None
# ...                                            ...         ...
# 18230449  5a5eb6bb04250b199a1cbb529e744075216a17a5        None
# 18230450  5a5eb6bb04250b199a1cbb529e744075216a17a5        None
# 18230451  5a5eb6bb04250b199a1cbb529e744075216a17a5        None
# 18230452  5a5eb6bb04250b199a1cbb529e744075216a17a5        None
# 18230453  4efb2a16dca28c1374be48dfaf4636d5bf167eba        None
#
# [8838996 rows x 7 columns]

# %%
merged_df = pd.merge(df1, df2,  how='inner', on="ref")
merged_df
# Out:
#          version                  timestamp provider  \
# 0              4  2020-06-18T16:41:00+00:00   GitHub
# 1              4  2020-06-18T16:42:00+00:00   GitHub
# 2              4  2020-06-18T16:43:00+00:00   GitHub
# 3              4  2020-06-18T16:44:00+00:00   GitHub
# 4              4  2020-06-18T16:44:00+00:00   GitHub
# ...          ...                        ...      ...
# 8409705        4  2021-06-06T23:43:00+00:00   GitHub
# 8409706        4  2021-06-06T23:52:00+00:00   GitHub
# 8409707        4  2021-06-06T23:52:00+00:00   GitHub
# 8409708        4  2021-06-06T23:55:00+00:00   GitHub
# 8409709        4  2021-06-06T23:54:00+00:00   GitHub
#
#                                                      spec            origin  \
# 0                      leosamu/pythonMoocCompanion/master  gke.mybinder.org
# 1                      leosamu/pythonMoocCompanion/master  gke.mybinder.org
# 2                      leosamu/pythonMoocCompanion/master  gke.mybinder.org
# 3                      leosamu/pythonMoocCompanion/master  gke.mybinder.org
# 4                      leosamu/pythonMoocCompanion/master  gke.mybinder.org
# ...                                                   ...               ...
# 8409705                              bodkan/smbe2021/main  gke.mybinder.org
# 8409706                             JJguri/bestiapop/HEAD  ovh.mybinder.org
# 8409707                       mzhao8/bear_classifier/HEAD  ovh.mybinder.org
# 8409708                       mzhao8/bear_classifier/HEAD  ovh.mybinder.org
# 8409709  ericmjl/bayesian-stats-modelling-tutorial/master  gke.mybinder.org
#
#                                               ref guessed_ref  \
# 0        e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# 1        e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# 2        e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# 3        e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# 4        e0fe196804caf9a1dbd18ed2c045d3cb902c3c55        None
# ...                                           ...         ...
# 8409705  64831e2cc32a4877c669b3d16156be7e2d25507d        None
# 8409706  2d5f216e18ac6ea8adc7f658d9bd344a49e7289c        None
# 8409707  95b20d80709832d340600461a86417ca5003bf7c        None
# 8409708  95b20d80709832d340600461a86417ca5003bf7c        None
# 8409709  89e97490d0c4cafd6da3ddab012d141df356acec        None
#
#                                                         ls  \
# 0        {".gitignore": 1879, "LICENSE": 1072, "PythonU...
# 1        {".gitignore": 1879, "LICENSE": 1072, "PythonU...
# 2        {".gitignore": 1879, "LICENSE": 1072, "PythonU...
# 3        {".gitignore": 1879, "LICENSE": 1072, "PythonU...
# 4        {".gitignore": 1879, "LICENSE": 1072, "PythonU...
# ...                                                    ...
# 8409705  {".gitignore": 40, "README.md": 1982, "SMBE202...
# 8409706  {".gitignore": 625, "LICENSE": 2615, "README.m...
# 8409707  {".gitignore": 1798, "bear_classifier.ipynb": ...
# 8409708  {".gitignore": 1798, "bear_classifier.ipynb": ...
# 8409709  {".azure-pipelines": {"azure-pipelines.yml": 1...
#
#                        runtime  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 8409705  b'r-3.6-2021-05-26\n'
# 8409706                   None
# 8409707                   None
# 8409708                   None
# 8409709                   None
#
#                                                        apt  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8409705  b'libudunits2-dev\ngdal-bin\nlibgdal-dev\nlibg...
# 8409706                                               None
# 8409707                                               None
# 8409708                                               None
# 8409709                                               None
#
#                                                      conda  \
# 0          name: python-upvx\nchannels:\n  - conda-forge\n
# 1          name: python-upvx\nchannels:\n  - conda-forge\n
# 2          name: python-upvx\nchannels:\n  - conda-forge\n
# 3          name: python-upvx\nchannels:\n  - conda-forge\n
# 4          name: python-upvx\nchannels:\n  - conda-forge\n
# ...                                                    ...
# 8409705                                               None
# 8409706  b'name: bestiapop\r\nchannels:\r\n  - conda-fo...
# 8409707                                               None
# 8409708                                               None
# 8409709  b'name: bayesian-modelling-tutorial\nchannels:...
#
#                                                        pip pipfile julia  \
# 0                                                     None    None  None
# 1                                                     None    None  None
# 2                                                     None    None  None
# 3                                                     None    None  None
# 4                                                     None    None  None
# ...                                                    ...     ...   ...
# 8409705                                               None    None  None
# 8409706                                               None    None  None
# 8409707  b'voila\nfastai>=2\npillow<7\npackaging\nipywi...    None  None
# 8409708  b'voila\nfastai>=2\npillow<7\npackaging\nipywi...    None  None
# 8409709                                               None    None  None
#
#                                                          r   nix docker  \
# 0                                                     None  None   None
# 1                                                     None  None   None
# 2                                                     None  None   None
# 3                                                     None  None   None
# 4                                                     None  None   None
# ...                                                    ...   ...    ...
# 8409705  b'install.packages("devtools")\ninstall.packag...  None   None
# 8409706                                               None  None   None
# 8409707                                               None  None   None
# 8409708                                               None  None   None
# 8409709                                               None  None   None
#
#                                                      setup  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 8409705                                               None
# 8409706  b'import sys\r\nfrom setuptools import setup\r...
# 8409707                                               None
# 8409708                                               None
# 8409709                                               None
#
#                                                  postbuild start
# 0                                                     None  None
# 1                                                     None  None
# 2                                                     None  None
# 3                                                     None  None
# 4                                                     None  None
# ...                                                    ...   ...
# 8409705  b'mkdir bin\n\n# installation instructions fro...  None
# 8409706                                               None  None
# 8409707                                               None  None
# 8409708                                               None  None
# 8409709                                               None  None
#
# [8409710 rows x 20 columns]

# %% [markdown]
# <a name='specs'></a>
# ## 3. Binder-Specs-EDA w/ clean_specs
#
# <br>
